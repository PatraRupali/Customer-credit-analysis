# %% [markdown]
# <a href="https://colab.research.google.com/github/PatraRupali/Customer-credit-analysis/blob/main/Credit_Data_Analysis_%26_Score_Development.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <font size =8 font color='blue'> ***Credit Data Analysis & Score Development***

# %% [markdown]
# ![dddd.PNG](data:image/png;base64,...)
